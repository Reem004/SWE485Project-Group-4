# %% [markdown]
# # Phase 4: Generative AI Integration
# ## SW485 - Machine Learning Project
# ### Disease Prediction System
#
# **Objective:**
# Integrate Generative AI (GPT) into our disease prediction system to provide detailed, personalized medical advice based on:
# - Disease predictions from Phase 2 (Supervised Learning)
# - Patient profiling from Phase 3 (Unsupervised Learning - Clustering)
#
# ---

# %% [markdown]
# ## Section 1: Libirary + API Setup and Configuration.
#
# We will be using GPT model as our api and below are our configuration steps:

# %%
import joblib
import pandas as pd
from openai import OpenAI
print("Librarires and OpenAI imported successfully!")
client = OpenAI(api_key="replace the key here")
# Out:
# Librarires and OpenAI imported successfully!

# %% [markdown]
# ###Test if the API is working:

# %%
response = client.chat.completions.create(
    model="gpt-4.1",
    messages=[{"role": "user", "content": "Hello, can you hear me?"}]
)

print(response.choices[0].message.content)
# Out:
# Hello! I can't actually "hear" you, but I can read your messages. How can I help you today?

# %% [markdown]
# now we will import the two models that we trained in previous phases:

# %% [markdown]
# Phase 2 Supervised Model:

# %%
rf_model = joblib.load('random_forest_model.pkl')
svm_model = rf_model = joblib.load('svm_model.pkl')
feature_columns = joblib.load('feature_columns.pkl')
print("Phase 2 models loaded succesfully")
# Out:
# Phase 2 models loaded succesfully

# %% [markdown]
# Phase 3 Unspervised Model:

# %%
nknkjn

# %% [markdown]
# njnjn
